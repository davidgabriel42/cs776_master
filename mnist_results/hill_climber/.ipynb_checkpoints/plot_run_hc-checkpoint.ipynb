# %%
# !pip install sklearn
# Out:
# Requirement already satisfied: sklearn in /home/djg/snap/jupyter/common/lib/python3.7/site-packages (0.0)
# Requirement already satisfied: scikit-learn in /home/djg/snap/jupyter/common/lib/python3.7/site-packages (from sklearn) (0.23.2)
# Requirement already satisfied: joblib>=0.11 in /home/djg/snap/jupyter/common/lib/python3.7/site-packages (from scikit-learn->sklearn) (0.17.0)
# Requirement already satisfied: numpy>=1.13.3 in /home/djg/snap/jupyter/common/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.18.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/djg/snap/jupyter/common/lib/python3.7/site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /home/djg/snap/jupyter/common/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.5.4)

# %%
from __future__ import print_function
import random as rand
import csv
import operator
import gc
import os
from datetime import datetime
from keras.callbacks import EarlyStopping
from keras.models import load_model
import keras.backend as K
from sklearn.metrics import log_loss
import numpy as np

if K.backend() == 'tensorflow':
    import tensorflow as tf
from setuptools import setup, find_packages

from keras.datasets import mnist
from keras.utils.np_utils import to_categorical
from keras import backend as K
#from devol import DEvol, GenomeHandler
import pandas as pd
from pyspark.sql.types import *
import inspect
from typing import Callable, List
import pandas as pd
from pyspark.sql import DataFrame, Row, column
from pyspark.sql.functions import lit, pandas_udf, PandasUDFType, array
from pyspark.sql.types import FloatType
# Out:
# /home/djg/snap/jupyter/common/lib/python3.7/site-packages/joblib/_multiprocessing_helpers.py:45: UserWarning: [Errno 13] Permission denied.  joblib will operate in serial mode
#   warnings.warn('%s.  joblib will operate in serial mode' % (e,))

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %% [markdown]
# # DEvol On MNIST Results
# ### Genome Record

# %%
# File location and type
file_location = "./Fri Dec 4 20 54 56 2020.csv"
file_type = "parquet"

# CSV options
infer_schema = "false"
first_row_is_header = "false"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = pd.read_csv(file_location, sep = delimiter).head(n=300)

display(df)
# Out:
#      Conv0 active  Conv0 num filters  Conv0 batch normalization  \
# 0               1                 16                          0
# 1               1                  8                          0
# 2               1                  8                          1
# 3               1                 64                          0
# 4               1                 64                          1
# ..            ...                ...                        ...
# 295             1                  8                          1
# 296             1                  8                          1
# 297             1                  8                          1
# 298             1                  8                          1
# 299             1                  8                          1
#
#      Conv0 activation  Conv0 dropout  Conv0 max pooling  Conv1 active  \
# 0                   0              7                  1             0
# 1                   1              6                  0             0
# 2                   1             10                  2             0
# 3                   0             10                  0             0
# 4                   0              3                  2             0
# ..                ...            ...                ...           ...
# 295                 0              9                  1             0
# 296                 0              9                  1             0
# 297                 0              9                  1             0
# 298                 0              9                  1             0
# 299                 0              9                  1             0
#
#      Conv1 num filters  Conv1 batch normalization  Conv1 activation  ...  \
# 0                   32                          0                 1  ...
# 1                   32                          0                 0  ...
# 2                   16                          1                 1  ...
# 3                   16                          1                 1  ...
# 4                   32                          0                 0  ...
# ..                 ...                        ...               ...  ...
# 295                 16                          0                 0  ...
# 296                 16                          0                 0  ...
# 297                 16                          0                 0  ...
# 298                 16                          0                 0  ...
# 299                 16                          0                 0  ...
#
#      Conv1 max pooling  Conv2 active  Conv2 num filters  \
# 0                    0             1                 64
# 1                    2             1                  8
# 2                    0             0                 16
# 3                    0             1                  8
# 4                    1             0                 64
# ..                 ...           ...                ...
# 295                  1             0                  8
# 296                  1             0                  8
# 297                  1             0                  8
# 298                  1             0                  8
# 299                  1             0                  8
#
#      Conv2 batch normalization  Conv2 activation  Conv2 dropout  \
# 0                            1                 1              5
# 1                            0                 0              3
# 2                            1                 1              1
# 3                            0                 0              1
# 4                            1                 1              2
# ..                         ...               ...            ...
# 295                          0                 0              7
# 296                          0                 0              7
# 297                          0                 0              7
# 298                          0                 0              7
# 299                          0                 0              7
#
#      Conv2 max pooling  Optimizer  Val Loss  Val Accuracy
# 0                    0          2  0.086492        0.9768
# 1                    1          0  0.093135        0.9745
# 2                    2          0  0.202798        0.9423
# 3                    0          2  0.052550        0.9832
# 4                    0          1  0.092450        0.9745
# ..                 ...        ...       ...           ...
# 295                  2          1  0.103196        0.9706
# 296                  2          1  0.108981        0.9725
# 297                  2          1  0.102880        0.9691
# 298                  2          1  0.086622        0.9743
# 299                  2          1  0.113127        0.9660
#
# [300 rows x 21 columns]

# %%
df['cummax'] = df['Val Accuracy'].cummax()
df
# Out:
#      Conv0 active  Conv0 num filters  Conv0 batch normalization  \
# 0               1                 16                          0
# 1               1                  8                          0
# 2               1                  8                          1
# 3               1                 64                          0
# 4               1                 64                          1
# ..            ...                ...                        ...
# 295             1                  8                          1
# 296             1                  8                          1
# 297             1                  8                          1
# 298             1                  8                          1
# 299             1                  8                          1
#
#      Conv0 activation  Conv0 dropout  Conv0 max pooling  Conv1 active  \
# 0                   0              7                  1             0
# 1                   1              6                  0             0
# 2                   1             10                  2             0
# 3                   0             10                  0             0
# 4                   0              3                  2             0
# ..                ...            ...                ...           ...
# 295                 0              9                  1             0
# 296                 0              9                  1             0
# 297                 0              9                  1             0
# 298                 0              9                  1             0
# 299                 0              9                  1             0
#
#      Conv1 num filters  Conv1 batch normalization  Conv1 activation  ...  \
# 0                   32                          0                 1  ...
# 1                   32                          0                 0  ...
# 2                   16                          1                 1  ...
# 3                   16                          1                 1  ...
# 4                   32                          0                 0  ...
# ..                 ...                        ...               ...  ...
# 295                 16                          0                 0  ...
# 296                 16                          0                 0  ...
# 297                 16                          0                 0  ...
# 298                 16                          0                 0  ...
# 299                 16                          0                 0  ...
#
#      Conv2 active  Conv2 num filters  Conv2 batch normalization  \
# 0               1                 64                          1
# 1               1                  8                          0
# 2               0                 16                          1
# 3               1                  8                          0
# 4               0                 64                          1
# ..            ...                ...                        ...
# 295             0                  8                          0
# 296             0                  8                          0
# 297             0                  8                          0
# 298             0                  8                          0
# 299             0                  8                          0
#
#      Conv2 activation  Conv2 dropout  Conv2 max pooling  Optimizer  Val Loss  \
# 0                   1              5                  0          2  0.086492
# 1                   0              3                  1          0  0.093135
# 2                   1              1                  2          0  0.202798
# 3                   0              1                  0          2  0.052550
# 4                   1              2                  0          1  0.092450
# ..                ...            ...                ...        ...       ...
# 295                 0              7                  2          1  0.103196
# 296                 0              7                  2          1  0.108981
# 297                 0              7                  2          1  0.102880
# 298                 0              7                  2          1  0.086622
# 299                 0              7                  2          1  0.113127
#
#      Val Accuracy  cummax
# 0          0.9768  0.9768
# 1          0.9745  0.9768
# 2          0.9423  0.9768
# 3          0.9832  0.9832
# 4          0.9745  0.9832
# ..            ...     ...
# 295        0.9706  0.9899
# 296        0.9725  0.9899
# 297        0.9691  0.9899
# 298        0.9743  0.9899
# 299        0.9660  0.9899
#
# [300 rows x 22 columns]

# %%
import matplotlib.pyplot as plt
fig = plt.figure() 
ax = fig.add_subplot(1, 1, 1) 
ax.plot(df.index, df['cummax'], color ='k') 

#fig, ax = plt.plot(df['cummax'])
ax.set_ylim(0.95,1)
ax.set_yticks(list(np.arange(0.95,1,0.005)))
ax.set_ylabel('Accuracy')

ax.set_xticks(list(np.arange(0,301,20)))
ax.set_xlabel('Fitness Evaluations')

ax.grid(color='k', linestyle='-.', linewidth=0.5)
ax.set_title('Hill Climber. Population size: 20')
# Out:
# Text(0.5, 1.0, 'Hill Climber. Population size: 20')
